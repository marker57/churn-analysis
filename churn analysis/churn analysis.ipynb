# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading Datasets

# %%
df=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
# df.reset_index(drop=True)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df["SeniorCitizen"]=df["SeniorCitizen"].replace(0,'No')
df["SeniorCitizen"]=df["SeniorCitizen"].replace(1,'Yes')
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# there is no missing value
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info
# Out:
# <bound method DataFrame.info of       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            No     Yes         No       1
# 1     5575-GNVDE    Male            No      No         No      34
# 2     3668-QPYBK    Male            No      No         No       2
# 3     7795-CFOCW    Male            No      No         No      45
# 4     9237-HQITU  Female            No      No         No       2
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.describe()
# Out:
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000

# %%
# how many total missing values do we have?
permiss=df.isnull().sum()
total_cells = np.product(df.shape)
total_missing = permiss.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## visualization

# %%
df['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
labels=['Male','Female']
gen=df['gender'].value_counts()
fig,ax=plt.subplots()
plt.pie(gen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.title('No of Gender with curn',fontsize=(32))
plt.legend()
plt.show()

# %%
gh=df['gender'].value_counts().plot(kind='bar',figsize=(15,7),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.xlabel('Gender',color='red',weight='bold')
plt.show()

# %% [markdown]
# ## Senior citizen

# %%
df['SeniorCitizen'].value_counts()
# Out:
# No     5901
# Yes    1142
# Name: SeniorCitizen, dtype: int64

# %%
labels=['No','Yes']
sen=df['SeniorCitizen'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('No of senior citizen that visits the telecommunication store',fontsize=23)
plt.show()

# %%
gh=df['SeniorCitizen'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('No of occurrence',weight='bold',color='red',fontsize=14)
plt.show()

# %% [markdown]
# ## Partner

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
labels=['No','Yes']
sen=df['Partner'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('No of customer that are married',fontsize=23)
plt.show()

# %%
gh=df['Partner'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('No of people with/without partners',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Dependants

# %%
df['Dependents'].value_counts()
# Out:
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
labels=['No','Yes']
sen=df['Dependents'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('No of Dependants',fontsize=23)
plt.show()

# %%
gh=df['Dependents'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('No of people with/without Dependents',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Phone services

# %%
labels=['No','Yes']
sen=df['PhoneService'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('No of people with phone services',fontsize=23)
plt.show()

# %%
gh=df['PhoneService'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('No of people with/without phone service',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## multiple lines

# %%
labels=['No','Yes','no phone service']
sen=df['MultipleLines'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1,0],autopct='%1.2f%%')
plt.legend()
plt.title('No of people with phone services',fontsize=23)
plt.show()

# %%
df['MultipleLines'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)

plt.xlabel('Multiple phone lines')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.title('People with multiple lines')
plt.show()

# %% [markdown]
# ## internet service

# %%
df['InternetService'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64

# %%
labels=['Fiber optic','DSL','No']
sen=df['InternetService'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1,0],autopct='%1.2f%%')
plt.legend()
plt.title('Types of internet services',fontsize=23)
plt.show()

# %%
gh=df['InternetService'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('No of people with/without phone service',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Device Protection

# %%
df['DeviceProtection'].value_counts()
# Out:
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64

# %%
labels=['No','Yes','No internet service']
sen=df['DeviceProtection'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1,0],autopct='%1.2f%%')
plt.legend()
plt.title('No of people with Device Protection',fontsize=23)
plt.show()

# %%
gh=df['DeviceProtection'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('No of people with device protection',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Contract

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
labels=['Month-to-month','Two year','One year']
sen=df['Contract'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1,0],autopct='%1.2f%%')
plt.legend()
plt.title('Time of Contract',fontsize=23)
plt.show()

# %%
gh=df['Contract'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('Time of Contract',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Paperless Billing

# %%
labels=['Yes','No']
sen=df['PaperlessBilling'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('Paperless Billing',fontsize=23)
plt.show()

# %%
gh=df['PaperlessBilling'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('Paperless Billing',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Payment Method

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
labels=['Electronic check','Mailed check','Bank transfer (automatic)','Credit card (automatic)']
sen=df['PaymentMethod'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0,0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('Payment Methods',fontsize=23)
plt.show()

# %%
gh=df['PaymentMethod'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('Payment Method',weight='bold',color='red')
plt.show()

# %% [markdown]
# ## Churn

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
labels=['No','Yes']
sen=df['Churn'].value_counts()
fig,ax=plt.subplots()
plt.pie(sen,labels=labels,explode=[0,0.1],autopct='%1.2f%%')
plt.legend()
plt.title('Paperless Billing',fontsize=23)
plt.show()

# %%
gh=df['Churn'].value_counts().plot(kind='bar',figsize=(18,6),color=sns.color_palette('dark'),rot=0)
for p in gh.patches:
    gh.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
plt.ylabel('no of occurence',weight='bold',color='red',fontsize=14)
plt.xlabel('No of people with/without phone service',weight='bold',color='red')
plt.show()

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.histplot(
    df,x='tenure',
    hue='Churn'
)
plt.show()

# %%
sns.displot(
    df,x='MonthlyCharges',
    col='Churn'
)

# %%
sns.catplot(
    data=df,
    x='MultipleLines',
    y='tenure',
    hue='Partner',
    kind='box',
    col='Churn'
)
plt.show()

# %%
sns.catplot(
    data=df,
    x='MultipleLines',
    y='MonthlyCharges',
    hue='Partner',
    kind='box',
    col='Churn'
)
plt.show()

# %%
sns.catplot(
    data=df,
    x='gender',
    y='tenure',
    hue='Partner',
    kind='box',
    col='Churn'
)
plt.show()

# %%
sns.catplot(
    data=df,
    x='gender',
    y='MonthlyCharges',
    hue='Partner',
    kind='box',
    col='Churn'
)
plt.show()

# %%
sns.relplot(
    data=df,
    x='MonthlyCharges',
    y='tenure',
    hue='Churn'
)
plt.figure(figsize=(18,7))

# %%
sns.displot(
    df,x='MonthlyCharges',
    hue='Churn',
    kind='kde',
)
plt.title('kde plot of monthly charges to churn')
plt.show()

# %%
sns.pointplot(
    data=df,
    x='InternetService',
    y='tenure',
    hue='Churn'

)
plt.title('the tenure of each customer internet service')
plt.show()

# %% [markdown]
# ## Indentations from dataset

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## The most used payment Method

# %%
# customer with the highest monthly charge
cust=df['PaymentMethod'].mode()[0]
print('The most used payment method is',cust)
# Out:
# The most used payment method is Electronic check

# %% [markdown]
# ## Number of customer that left within a month

# %%
leftmont=df[df['tenure']<30]['customerID'].count()
print('The number of customer that left within a month is',leftmont)
# Out:
# The number of customer that left within a month is 3569

# %% [markdown]
# ## The average monthly charge

# %%
avgcharge=df['MonthlyCharges'].mean()
print('The average monthly charge is:',avgcharge)
# Out:
# The average monthly charge is: 64.76169246059922

# %%
avgmale=df[df['gender']=='Male']['MonthlyCharges'].mean()
avgfemale=df[df['gender']=='Female']['MonthlyCharges'].mean()
print('The average monthly charges for male is:',avgmale)
print('The average monthly charge for Female is: ',avgfemale)
# Out:
# The average monthly charges for male is: 64.32748241912773
# The average monthly charge for Female is:  65.20424311926602
